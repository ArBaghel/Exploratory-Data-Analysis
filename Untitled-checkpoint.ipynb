# %%
#Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(color_codes=True)

# %%
df=pd.read_csv(r"automobile.csv")
df.head(2)
# Out:
#    Unnamed: 0  price   brand    model  year   title_status  mileage   color  \
# 0           0   6300  toyota  cruiser  2008  clean vehicle   274117   black
# 1           1   2899    ford       se  2011  clean vehicle   190552  silver
#
#                    vin        lot       state country     condition
# 0    jtezu11f88k007763  159348797  new jersey     usa  10 days left
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa   6 days left

# %%
df.tail(5)
# Out:
#       Unnamed: 0  price   brand  model  year   title_status  mileage   color  \
# 2494        2494   7800  nissan  versa  2019  clean vehicle    23609     red
# 2495        2495   9200  nissan  versa  2018  clean vehicle    34553  silver
# 2496        2496   9200  nissan  versa  2018  clean vehicle    31594  silver
# 2497        2497   9200  nissan  versa  2018  clean vehicle    32557   black
# 2498        2498   9200  nissan  versa  2018  clean vehicle    31371  silver
#
#                       vin        lot       state country      condition
# 2494    3n1cn7ap9kl880319  167722715  california     usa    1 days left
# 2495    3n1cn7ap5jl884088  167762225     florida     usa  21 hours left
# 2496    3n1cn7ap9jl884191  167762226     florida     usa  21 hours left
# 2497    3n1cn7ap3jl883263  167762227     florida     usa    2 days left
# 2498    3n1cn7ap4jl884311  167762228     florida     usa  21 hours left

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# price            int64
# brand           object
# model           object
# year             int64
# title_status    object
# mileage          int64
# color           object
# vin             object
# lot              int64
# state           object
# country         object
# condition       object
# dtype: object

# %%
  df.rename(columns={"price":"Price","brand":"Brand","model":"Model","title_status":"Vehicle Status",
"year":"Year","color":"Color","state":"State","country":"Country","condition":"Condition","milage":"Milage"},inplace=True)
df.head(7)
# Out:
#    Unnamed: 0  Price      Brand    Model  Year Vehicle Status  mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle   274117
# 1           1   2899       ford       se  2011  clean vehicle   190552
# 2           2   5350      dodge      mpv  2018  clean vehicle    39590
# 3           3  25000       ford     door  2014  clean vehicle    64146
# 4           4  27700  chevrolet     1500  2018  clean vehicle     6654
# 5           5   5700      dodge      mpv  2018  clean vehicle    45561
# 6           6   7300  chevrolet       pk  2010  clean vehicle   149050
#
#     Color                  vin        lot       State Country      Condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# ...

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
df=df.drop(['vin','lot'],axis=1)
df.head(3)
# Out:
#    Unnamed: 0  Price   Brand    Model  Year Vehicle Status  mileage   Color  \
# 0           0   6300  toyota  cruiser  2008  clean vehicle   274117   black
# 1           1   2899    ford       se  2011  clean vehicle   190552  silver
# 2           2   5350   dodge      mpv  2018  clean vehicle    39590  silver
#
#         State Country     Condition
# 0  new jersey     usa  10 days left
# 1   tennessee     usa   6 days left
# 2     georgia     usa   2 days left

# %%
print(df.isnull().sum())
df=df.dropna()
df.count()
# Out:
# Unnamed: 0        0
# Price             0
# Brand             0
# Model             0
# Year              0
# Vehicle Status    0
# mileage           0
# Color             0
# State             0
# Country           0
# Condition         0
# dtype: int64
# Unnamed: 0        2499
# Price             2499
# Brand             2499
# Model             2499
# Year              2499
# Vehicle Status    2499
# mileage           2499
# Color             2499
# State             2499
# Country           2499
# Condition         2499
# dtype: int64

# %%
df.shape
# Out:
# (2499, 11)

# %%
df=df[df.duplicated()]
print("duplicate rows are :",df.shape)
df.count()
# Out:
# duplicate rows are : (0, 11)
# Unnamed: 0        0
# Price             0
# Brand             0
# Model             0
# Year              0
# Vehicle Status    0
# mileage           0
# Color             0
# State             0
# Country           0
# Condition         0
# dtype: int64

# %%
df.Brand.value_counts().nlargest(40).plot(kind='bar',figsize=(18,5))
plt.title("No. of Cars by Brands")
plt.ylable("No. of Cars")
plt.xlable("Brand");
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.Brand.value_counts().nlargest(40).plot(kind='bar',figsize=(18,5))
#       2 plt.title("No. of Cars by Brands")
#       3 plt.ylable("No. of Cars")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...
